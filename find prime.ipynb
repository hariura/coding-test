# %%
def solution(n):
    primes = [2]
    for i in range(3,n+1):
        print(i)
        for prime in primes:
            if i%prime != 0:
                primes.append(i)
    print(primes)
    answer = len(primes)
    return answer

# %%
solution(5)
# Out:
# 3
# 4
# 5
# [2, 3, 4, 5, 5, 5]
# 6

# %%
def solution(n):
    primes = [2]
    if n == 2 : return 1
    for i in range(3,n+1): # 3부터 n까지
        for prime in primes:
            if i%prime !=0:
