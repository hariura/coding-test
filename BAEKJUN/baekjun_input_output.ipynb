# %% [markdown]
# 이 문제는 개같은것이 다 스트링으로 들어와서 그런거네
# 아 쫌 친절하게 인풋 좀 주지 개같은새끼

# %%
#띄어쓰기 없는 인풋
graph_size = int(input())
graph = [list(input()) for _ in range(graph_size)]

# %%
# int로 받을꺼면 그냥 무조건 ! 라인으로 받아라

# %%
# 스트링으로 그래프 되어있는거 미칠거같아
N = int(input())

maps = []
for _ in range(N):
    line = input().rstrip()
    maps.append(list(map(int,list(line))))

# %%
# 띄어쓰기 있는 인풋

N, M = map(int, input().split())

for row in range(N):
    row = list(map(int, input().split()))
    A.append(row)
