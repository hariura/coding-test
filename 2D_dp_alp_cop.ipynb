# %%
alp = 10
cop = 10
problems = [[10,15,2,1,2],[20,20,3,3,4]]

# %%
def solution(alp, cop, problems):
    INF = float("inf")
    problems.append([0,0,0,1,1])
    problems.append([0,0,1,0,1])
    max_alp, max_cop = max([i[0] for i in problems]), max([i[1] for i in problems])
    dp = [[INF]*(max_cop+1) for _ in range(max_alp+1)]
    alp = min(alp,max_alp)
    cop = min(cop,max_cop)
    dp[alp][cop] = 0
    for i in range(alp,max_alp+1):
        for j in range(cop, max_cop+1):
            for alp_req, cop_req, alp_rwd, cop_rwd, cost in problems:
                if i>=alp_req and j>=cop_req:
                    next_alp, next_cop = min(max_alp,i+alp_rwd), min(max_cop,j+cop_rwd)
                    dp[next_alp][next_cop] = min(dp[next_alp][next_cop], dp[i][j] + cost)
#     print(dp)
    return dp[-1][-1]

# %%
solution(alp, cop, problems)
# Out:
# 15

# %%
def solution(alp, cop, problems):
    #최단시간 :dp??
    inf = 10 ** 6
    problems.append([0,0,0,1,1])
    problems.append([0,0,1,0,1])
    max_alp, max_cop = max([i[0] for i in problems]), max([i[1] for i in problems])
    dp = [[inf for _ in range(max_alp + 1)] for _ in range(max_cop + 1)]#걸린 시간을 담는 배열
    if max_alp <= alp:
        alp = max_alp
    if max_cop <= cop:
        cop = max_cop
    dp[cop][alp] = 0
    #여기까즤..완벽!
    for i in range(cop, max_cop + 1):
        for j in range(alp, max_alp + 1):
            for alp_req, cop_req, alp_rwd, cop_rwd, cost in problems:
                if i >= cop_req and j >= alp_req:
                    k = i + cop_rwd if i + cop_rwd < max_cop else max_cop 
                    l = j + alp_rwd if j + alp_rwd < max_alp else max_alp
                    dp[k][l] = min([dp[k][l], dp[i][j] + cost])
    return dp[-1][-1]

# %%
def solution(alp, cop, problems):
    max_alp = 0 
    max_cop = 0
    for a,b,c,d,e in problems:
        max_alp = max(max_alp,a)
        max_cop = max(max_cop,b)
    
    alp = min(alp, max_alp)
    cop = min(cop, max_cop)
    INF = float('inf')
    dp = [[INF]*(max_cop+1) for _ in range(max_alp+1)]
    dp[alp][cop] = 0
    for i in range(alp,max_alp+1):
        for j in range(cop,max_cop+1):
            if i + 1 <= max_alp:
                dp[i+1][j] = min(dp[i+1][j], dp[i][j]+1)
            if j+1 <= max_cop:
                dp[i][j+1] = min(dp[i][j+1], dp[i][j]+1)
            
            for alp_req,cop_req,alp_rwd,cop_rwd,cost in problems:
                # 현재 i,j 로 풀수있다면
                if i >= alp_req and j >= cop_req:
                    # 풀어서 얻은 내 최종 알고,코딩력이 max_alp,max_cop 보다크면 그대로 max_alp,max_cop 에 저장 
                    next_alp,next_cop = min(max_alp,i + alp_rwd), min(max_cop,j + cop_rwd)
                    dp[next_alp][next_cop] = min(dp[next_alp][next_cop],dp[i][j] + cost)
    return dp[-1][-1]
    # return answer

# %%
def solution(alp, cop, problems):
    max_alp = 0
    max_cop = 0
    for a,b,c,d,e in problems:
        max_alp = max(max_alp,a)
        max_cop = max(max_cop,b)
    # max_alp,max_cop 가  초기값보다 낮을수도있으므로 세팅
    alp = min(alp,max_alp)
    cop = min(cop,max_cop)
    INF = float('inf')
    dp = [[INF]*(max_cop + 1) for _ in range(max_alp + 1)]
    dp[alp][cop] = 0
    for i in range(alp, max_alp + 1):
        for j in range(cop, max_cop + 1):
            # 배열 범위벗어나지않게 
            if i + 1 <= max_alp:
                dp[i + 1][j    ] = min (dp[i + 1][j    ],dp[i][j] + 1)
            if j + 1 <= max_cop:
                dp[i    ][j + 1] = min (dp[i    ][j + 1],dp[i][j] + 1)

            # 모든문제 순회 하면서 
            for alp_req,cop_req,alp_rwd,cop_rwd,cost in problems:
                # 현재 i,j 로 풀수있다면
                if i >= alp_req and j >= cop_req:
                    # 풀어서 얻은 내 최종 알고,코딩력이 max_alp,max_cop 보다크면 그대로 max_alp,max_cop 에 저장 
                    next_alp,next_cop = min(max_alp,i + alp_rwd), min(max_cop,j + cop_rwd)
                    dp[next_alp][next_cop] = min(dp[next_alp][next_cop],dp[i][j] + cost)
    return dp[-1][-1]

# %%
#2024/1/6 풀이 

def solution(alp, cop, problems):
    #준비단계 
    float = int(1e9)
    problems.append([0,0,1,0,1])
    problems.append([0,0,0,1,1])
    max_alp = max([problem[0] for problem in problems])
    max_cop = max([problem[1] for problem in problems])
    
    # 예외처리 
    max_alp = max(alp,max_alp)
    max_cop = max(cop,max_cop)
    
    # 나이브한 dp 
    dp = [[float]*(max_cop+1) for _ in range(max_alp+1)] #처음에 알고력이 0부터 시작하고 max 보다 1 작잖아 왜냐 ? 이건 인덱스로 들어가니까
    #인덱스인지, 숫자인지 인지하고 들어가자 
    # inital value
    dp[alp][cop] = 0
    
    for i in range(alp, max_alp+1):
        for j in range(cop, max_cop+1):
            for alp_req, cop_req, alp_rwd, cop_rwd, cost in problems:
                # if i>= alp_req and j>= cop_req: # 문제를 먼저 풀어야함
                #     if dp[i + alp_rwd][j + cop_rwd] <= dp[i][j] + cost:
                #         dp[i + alp_rwd][j + cop_rwd] = dp[i][j] + cost # 더 작으면 업데이트
                if i>= alp_req and j>= cop_req: # 문제를 먼저 풀어야함
                    k = i + alp_rwd if i + alp_rwd < max_alp else max_alp # else는 업데이트 하지 않도록 하기 위해서 큰숫자 박는거임
                    l = j + cop_rwd if j + cop_rwd < max_cop else max_cop
                    dp[k][l] = min(dp[k][l], dp[i][j]+cost)
                    
    answer = dp[-1][-1]
    return answer

# %%
#2024/1/8풀이 

def solution(alp, cop, problems):
    #준비단계 
    float = int(1e9)
    problems.append([0,0,1,0,1])
    problems.append([0,0,0,1,1])
    max_alp = max([problem[0] for problem in problems])
    max_cop = max([problem[1] for problem in problems])
    
    # 예외처리 
    max_alp = max(alp,max_alp)
    max_cop = max(cop,max_cop)
    
    # 나이브한 dp 
    dp = [[float]*(max_cop+1) for _ in range(max_alp+1)] #처음에 알고력이 0부터 시작하고 max 보다 1 작잖아 왜냐 ? 이건 인덱스로 들어가니까
    #인덱스인지, 숫자인지 인지하고 들어가자 
    # inital value
    dp[alp][cop] = 0
    
    for i in range(alp, max_alp+1):
        for j in range(cop, max_cop+1):
            for alp_req, cop_req, alp_rwd, cop_rwd, cost in problems:
                if i>= alp_req and j>= cop_req: # 문제를 먼저 풀어야함
                    # 이때 이해를 못했던게 넘어가면 스킵이 아니라 이렇게 나타냈네? 
                    # 근데 이후에 생각하니까 달성하기만 하면 되는거라서, 넘어가는건 가장 마지막 애 가지고만 나타내면 되는거였어.
                    # 예외처리에서 생각해야하는 부분 밖으로 나가는 부분부터 다시 공부해보자 
                    next_alp, next_cop = min(max_alp, i+alp_rwd), min(max_cop, j+cop_rwd)
                    dp[next_alp][next_cop] = min(dp[next_alp][next_cop], dp[i][j]+cost)
    answer = dp[-1][-1]
    return answer
