# %%
stack = []
stack.append(1)
stack.append(2)
stack
# Out:
# [1, 2]

# %%
stack.pop()
# Out:
# 2

# %%
stack
# Out:
# [1]

# %%
from collections import deque

queue = deque()

queue.append(5)
queue.append(3)
queue.append(2)
queue.append(3)

queue
# Out:
# deque([5, 3, 2, 3])

# %%
queue.popleft()
# Out:
# 5

# %%
queue
# Out:
# deque([3, 2, 3])

# %%
queue.reverse()

# %%
queue
# Out:
# deque([3, 2, 3, 5])

# %%
queue.popleft()
# Out:
# 3

# %%
def dfs(graph, v, visited):
    visited[v] = True
    print(v, end = " ")
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# %%
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

# %%
#인덱스 0 사용안함
visited = [False]*9

# %%
dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %%
graph = [
    [],
    [2],
    [1,5],
    [4],
    [3,5,7],
    [2,4,7],
    [7],
    [4,5,6,8],
    [7]

]

# %%
from collections import deque

def bfs(graph, start, visited):
    queue = deque([start])
    visited[start] = True
    
    while queue:
        # 큐에서 하나의 원소를 뽑아 출력하기
        v = queue.popleft()
        print(v, end=" ")
        # 아직 방문하지 않은 인접한 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

# %%
visited = [False]*9

# %%
bfs(graph, 2, visited)
# Out:
# 2 1 5 4 7 3 6 8

# %%
# tickets = [["ICN", "JFK"], ["HND", "IAD"], ["JFK", "HND"]]
tickets = [["ICN", "SFO"], ["ICN", "ATL"], ["SFO", "ATL"], ["ATL", "ICN"], ["ATL","SFO"]]

# %%
# 방문 처리 없다. 
def solution(tickets):
    routes = {}
    for t in tickets:
        routes[t[0]] = routes.get([t[0]], []) + [t[1]]
    for r in routes:
        routes[r].sorts(reverse = True)
        
    stack = ["ICN"]
    path = []
    while stack :
        top = stack[-1]
        
        if top not in routes or len(routes[top]) ==0 : 
            path.append(stack.pop())
        else :
            stack.append(routes[top].pop())
    return path[::-1]

# %%
solution(tickets)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 solution(tickets)
#
# Cell In[40], line 5, in solution(tickets)
#       3 routes = {}
#       4 for t in tickets:
# ----> 5     routes[t[0]] = routes.get([t[0]], []) + [t[1]]
#       6 for r in routes:
#       7     routes[r].sorts(reverse = True)
#
# TypeError: unhashable type: 'list'

# %%
# 방문 처리 없다. 
def solution(tickets):
    routes = {}
    for t in tickets:
        routes[t[0]] = routes.get([t[0]], []) + [t[1]]
    for r in routes:
        routes[r].sorts(reverse = True)
        
    stack = ["ICN"]
    path = []
    while len(stack)>0 :
        top = stack[-1]
        
        if top not in routes or len(routes[top]) ==0 : 
            path.append(stack.pop())
        else:
            stack.append(routes[top][-1])
            routes[top] = routes[top][:-1]
    return path[::-1]

# %%
solution(tickets)
# Out:
# ['ICN', 'ATL', 'ICN', 'SFO', 'ATL', 'SFO']

# %%
# 방문 처리 없다. 
def solution(tickets):
    routes = {}
    for t in tickets:
        routes[t[0]] = routes.get(t[0], []) + [t[1]]
    for r in routes:
        routes[r].sort(reverse=True)
    stack = ["ICN"]
    
    path = []
    while stack :
        top = stack[-1]
        
        if top not in routes or len(routes[top]) ==0 : 
            path.append(stack.pop())
        else :
            stack.append(routes[top].pop())
    return path[::-1]

# %%
solution(tickets)
# Out:
# ['ICN', 'ATL', 'ICN', 'SFO', 'ATL', 'SFO']
