# %% [markdown]
# ## 스택
# 선입 후출 자료구조
# **박스쌓기**, 입구와 출구가 동일한 형태

# %%
stack = []
stack.append(3)
stack.pop()

# %% [markdown]
# ## 큐
# 선입 선출
# 큐는 입구와 출구가 모두 뚤려있는 터널과 같은 형태
# 대기열
# 왼쪽으로 들어와서 오른쪽으로 나간다고 생각중

# %%
from collections import deque
#덱 라이브러리

# 큐(queue) 구현을 위해 deque 라이브러리를 사용
# 사용 안하면 시간복잡도 늘어남

queue = deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
# Out:
# 5

# %%
print(queue)
# Out:
# deque([2, 3, 7])

# %%
queue.reverse()
print(queue)
# Out:
# deque([7, 3, 2])

# %% [markdown]
# 재귀 함수 (Recursive Function)란 자기 자신을 호출하는 함수를 의미합니다.

# %%
def recursive_fucntion():
    print("재귀 함수 출력 ")
    recursive_fucntion()

# %%
recursive_fucntion()
# Out:
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# ...

# %% [markdown]
# 스택구조안에 함수가 들어간다?
# 종료 조건을 넣어줘야 명시해야한다.

# %%
def recursive_fucntion(i):
    if i ==100:
        return
    print("재귀 함수 출력 ")
    recursive_fucntion(i+1)

# %%
recursive_fucntion(1)
# Out:
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# 재귀 함수 출력
# ...

# %%
def factorial_recursive(n):
    if n<= 1:
        return 1
    return n*factorial_recursive(n-1)

# %%
factorial_recursive(5)
# Out:
# 120

# %% [markdown]
# 유클리드 호제법

# %%
def gcd(a,b):
    if a%b ==0:
        return b
    else:
        return gcd(b,a%b)

# %%
print(gcd(192,162))
# Out:
# 6

# %% [markdown]
# ## Depth-First search

# %% [markdown]
# - 깊이 우선 탐색. 깊은 부분을 우선적으로 탐색하는 알고리즘
# - 스택자료구조(혹은 재귀함수)를 사용함
# 1. 탐색 시작 노드를 스택에 삽입하고 방문처리를 함
# 2. 스택의 최상단 노드에 방문하지 않은 인접한 노드가 하나라도 있으면 그 노드를 스택에 넣고 방문 처리를 합니다. 방문하지 않은 인접 노드가 없으면 스택에서 최상단 노드를 꺼냅니다.
# 3. 더이상 2번의 과정을 수행할 수 없을 때까지 반복합니다.
#
# - 황진경코딩영재AI학원에서 강의를 듣고, 알고리즘과 코드를 매칭 할 수 있었음.
# - 뎁스 : 재귀함수 콜하는 개수로 의미. 트리에서 몇번이나 내려갈건지
# - 포문 돌아야하는거 : 주사위 1~6, 2차원 상하좌우

# %% [markdown]
# 방문기준 : 번호가 낮은 인접 노드 부터 함.

# %%
def dfs(graph, v, visited):
    visited[v] = True
    print(v,end = " ")
    # 현재 노드와 관련된 다른 노드를 재귀적으로 방문 
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# %%
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

# %%
#인덱스 0 사용안함
visited = [False]*9

# %%
dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %% [markdown]
# ## BFS(Breadth-First Search)
# - BFS는 너비 우선 탐색, 그래프에서 가까운 노드부터 우선적으로 탐색
# - BFS는 큐 자료구조를 이용
# 1. 탐색 시작 노드를 큐에 삽입하고 방문 처리를 합니다.
# 2. 큐에서 노드를 꺼낸 뒤 해당 노드의 인접 노드중 방문하지 않은 노드를 모두 큐에 삽입하고 방문 처리합니다.
# 3. 더이상 2번 과정을 수행할 수 없을 때 까지 반복합니다.

# %% [markdown]
# 방문 할때 가까운 것부터 탐색
# 최단거리 문제 해결

# %%
from collections import deque

def bfs(graph, start, visited):
    queue = deque([start])
    visited[start] = True
    
    while queue:
        # 큐에서 하나의 원소를 뽑아 출력하기
        v = queue.popleft()
        print(v, end=" ")
        # 아직 방문하지 않은 인접한 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

# %%
visited = [False]*9

# %%
bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %% [markdown]
# 음료수 얼려먹기

# %%
n, m = map(int,input().split())

graph = []
for i in range(n):
    graph.append(list(map(int, input())))
# Out:
# 3 3
# 001
# 010
# 101

# %%
def dfs(x, y):
    if x<= -1 or x>= n or y<= -1 or y>=m:
        return False
    if graph[x][y]==0:
        #해당노드 방문 처리 
        graph[x][y] = 1
        # 상,하, 좌, 우의 위치에서도 모두 재귀적으로 호출
        dfs(x-1 ,y)
        dfs(x ,y-1)
        dfs(x+1 ,y)
        dfs(x ,y+1)
        return True
    return False

result = 0
for i in range(n):
    for j in range(m):
        # 현재위치에서 DFS 수행
        if dfs(i,j) == True :
            # 방문하지 않았다면 1추가하기
            result += 1
print(result)
# Out:
# 3

# %% [markdown]
# 미로탈출
# - 간선의 길이가 모두 같을때 최단거리 탐색 알고리즘
# - 큐가 빌대까지 dfs를 반복한다?

# %% [markdown]
# 여행경로
# - 이렇게 짜면 깊이 우선탐색이래
# - 첫번째로 dict 구조를 사용했다.
# - dfs 재귀함수를 사용을 안했지만 stack으로 dfs를 진행했다.
# - 과연 나는 이걸 짤 수 있나 ?

# %%
# tickets = [["ICN", "JFK"], ["HND", "IAD"], ["JFK", "HND"]]
tickets = [["ICN", "SFO"], ["ICN", "ATL"], ["SFO", "ATL"], ["ATL", "ICN"], ["ATL","SFO"]]

# %%
def solution(tickets):
    routes = {}
    for t in tickets:
        routes[t[0]] = routes.get(t[0], []) + [t[1]]
    for r in routes:
        routes[r].sort(reverse=True)
    stack = ["ICN"]
    path = []
    while len(stack) > 0:
        top = stack[-1]
        if top not in routes or len(routes[top]) == 0:
            path.append(stack.pop())
        else:
            stack.append(routes[top][-1])
            routes[top] = routes[top][:-1]
    return path[::-1]
